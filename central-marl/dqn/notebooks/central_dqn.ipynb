# %%
import gym 
import rware 
import numpy as np 
import jax.numpy as jnp
import jax
import haiku as hk
from typing import Optional
import jax.random as random

# %%
import gym
env = gym.make("rware:rware-tiny-2ag-v1")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 import gym
# ----> 2 env = gym.make("rware:rware-tiny-2ag-v1")
#
# File ~/miniconda3/envs/ray-par-env/lib/python3.8/site-packages/gym/envs/registration.py:640, in make(id, max_episode_steps, autoreset, apply_api_compatibility, disable_env_checker, **kwargs)
#     637     render_mode = None
#     639 try:
# --> 640     env = env_creator(**_kwargs)
#     641 except TypeError as e:
#     642     if (
#     643         str(e).find("got an unexpected keyword argument 'render_mode'") >= 0
#     644         and apply_human_rendering
#     645     ):
#
# File ~/miniconda3/envs/ray-par-env/lib/python3.8/site-packages/rware/warehouse.py:247, in Warehouse.__init__(self, shelf_columns, column_height, shelf_rows, n_agents, msg_bits, sensor_range, request_queue_size, max_inactivity_steps, max_steps, reward_type, fast_obs, layout)
#     245 self.fast_obs = None
#     246 self.observation_space = None
# --> 247 self._use_slow_obs()
#     249 # for performance reasons we
#     250 # can flatten the obs vector
#     251 if fast_obs:
#
# File ~/miniconda3/envs/ray-par-env/lib/python3.8/site-packages/rware/warehouse.py:313, in Warehouse._use_slow_obs(self)
#     309 def _use_slow_obs(self):
#     310     self.fast_obs = False
#     311     self.observation_space = spaces.Tuple(
#     312         tuple(
# --> 313             [
#     314                 spaces.Dict(
#     315                     OrderedDict(
#     316                         {
#     317                             "self": spaces.Dict(
#     318                                 OrderedDict(
#     319                                     {
#     320                                         "location": spaces.Box(
#     321                                             low=0,
#     322                                             high=np.array(
#     323                                                 [
#     324                                                     self.grid_size[1],
#     325                                                     self.grid_size[0],
#     326                                                 ]
#     327                                             ),
#     328                                             dtype=int,
#     329                                         ),
#     330                                         "carrying_shelf": spaces.MultiBinary(1),
#     331                                         "direction": spaces.Discrete(4),
#     332                                         "on_highway": spaces.MultiBinary(1),
#     333                                     }
#     334                                 )
#     335                             ),
#     336                             "sensors": spaces.Tuple(
#     337                                 self._obs_sensor_locations
#     338                                 * (
#     339                                     spaces.Dict(
#     340                                         OrderedDict(
#     341                                             {
#     342                                                 "has_agent": spaces.MultiBinary(1),
#     343                                                 "direction": spaces.Discrete(4),
#     344                                                 "local_message": spaces.MultiBinary(
#     345                                                     self.msg_bits
#     346                                                 ),
#     347                                                 "has_shelf": spaces.MultiBinary(1),
#     348                                                 "shelf_requested": spaces.MultiBinary(
#     349                                                     1
#     350                                                 ),
#     351                                             }
#     352                                         )
#     353                                     ),
#     354                                 )
#     355                             ),
#     356                         }
#     357                     )
#     358                 )
#     359                 for _ in range(self.n_agents)
#     360             ]
#     361         )
#     362     )
#
# File ~/miniconda3/envs/ray-par-env/lib/python3.8/site-packages/rware/warehouse.py:344, in <listcomp>(.0)
#     309 def _use_slow_obs(self):
#     310     self.fast_obs = False
#     311     self.observation_space = spaces.Tuple(
#     312         tuple(
#     313             [
#     314                 spaces.Dict(
#     315                     OrderedDict(
#     316                         {
#     317                             "self": spaces.Dict(
#     318                                 OrderedDict(
#     319                                     {
#     320                                         "location": spaces.Box(
#     321                                             low=0,
#     322                                             high=np.array(
#     323                                                 [
#     324                                                     self.grid_size[1],
#     325                                                     self.grid_size[0],
#     326                                                 ]
#     327                                             ),
#     328                                             dtype=int,
#     329                                         ),
#     330                                         "carrying_shelf": spaces.MultiBinary(1),
#     331                                         "direction": spaces.Discrete(4),
#     332                                         "on_highway": spaces.MultiBinary(1),
#     333                                     }
#     334                                 )
#     335                             ),
#     336                             "sensors": spaces.Tuple(
#     337                                 self._obs_sensor_locations
#     338                                 * (
#     339                                     spaces.Dict(
#     340                                         OrderedDict(
#     341                                             {
#     342                                                 "has_agent": spaces.MultiBinary(1),
#     343                                                 "direction": spaces.Discrete(4),
# --> 344                                                 "local_message": spaces.MultiBinary(
#     345                                                     self.msg_bits
#     346                                                 ),
#     347                                                 "has_shelf": spaces.MultiBinary(1),
#     348                                                 "shelf_requested": spaces.MultiBinary(
#     349                                                     1
#     350                                                 ),
#     351                                             }
#     352                                         )
#     353                                     ),
#     354                                 )
#     355                             ),
#     356                         }
#     357                     )
#     358                 )
#     359                 for _ in range(self.n_agents)
#     360             ]
#     361         )
#     362     )
#
# File ~/miniconda3/envs/ray-par-env/lib/python3.8/site-packages/gym/spaces/multi_binary.py:44, in MultiBinary.__init__(self, n, seed)
#      42     self.n = n = int(n)
#      43     input_n = (n,)
# ---> 44     assert (np.asarray(input_n) > 0).all()  # n (counts) have to be positive
#      46 super().__init__(input_n, np.int8, seed)
#
# AssertionError:
